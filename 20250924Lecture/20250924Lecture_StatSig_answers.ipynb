# %% [markdown]
# # CP201A Lecture: Testing for Statistical Significance
# Fall 2025
#
# Today, we're going to answer the question:  Which county saw the greatest increases in median rents between 2019 and 2023?

# %%
# Import the libraries and modules we need
import pandas as pd
from census import Census
import numpy as np

# %%
# Initialize the Census Data API connection with your API key
api_key = 'ab895c1f94c45324d4cfa4f724f1aec7f1a274a4'
c = Census(key=api_key)

# Define the dict of variables to pull and rename
variables_of_interest = {
    'NAME': 'NAME',
    'GEO_ID': 'GEO_ID',
    'B25064_001E': 'med_rent',
    'B25064_001M': 'med_rent_moe',
}

# Pull 2019
df_2019 = pd.DataFrame(
    c.acs1.get(
        list(variables_of_interest.keys()),
        {'for': 'county:*', 'in':'state:06'},
        year=2019
    )
).rename(columns=variables_of_interest)

# Pull 2023
df_2023 = pd.DataFrame(
    c.acs1.get(
        list(variables_of_interest.keys()),
        {'for': 'county:*', 'in':'state:06'},
        year=2023
    )
).rename(columns=variables_of_interest)

# %%
df_2019 = df_2019.rename(
    columns={
        "med_rent": "med_rent_2019",
        "med_rent_moe": "med_rent_2019_moe"
    }
)

df_2023 = df_2023.rename(
    columns={
        "med_rent": "med_rent_2023",
        "med_rent_moe": "med_rent_2023_moe"
    }
)

# Merge and keep NAME from 2023
df_merged = pd.merge(
    df_2019[["state", "county", "med_rent_2019", "med_rent_2019_moe"]],
    df_2023[["state", "county", "NAME", "med_rent_2023", "med_rent_2023_moe"]],
    on=["state", "county"],
    how="inner"
)

df = df_merged[[
    "NAME", 
    "med_rent_2019", 
    "med_rent_2019_moe", 
    "med_rent_2023", 
    "med_rent_2023_moe"
]].copy()
df
# Out:
#                                   NAME  med_rent_2019  med_rent_2019_moe  \
# 0              Lake County, California          992.0              202.0
# 1              Yuba County, California         1012.0               80.0
# 2            Sonoma County, California         1757.0               57.0
# 3          Imperial County, California          810.0               75.0
# 4           Alameda County, California         1982.0               41.0
# 5              Napa County, California         1835.0              124.0
# 6              Yolo County, California         1489.0               74.0
# 7            Nevada County, California         1407.0              130.0
# 8         Mendocino County, California         1120.0              103.0
# 9       Los Angeles County, California         1577.0                9.0
# 10      Santa Clara County, California         2392.0               31.0
# 11           Merced County, California         1097.0               62.0
# 12     Contra Costa County, California         1948.0               50.0
# 13       Stanislaus County, California         1231.0               39.0
# 14    Santa Barbara County, California         1660.0               54.0
# 15           Tehama County, California          950.0              161.0
# 16       Sacramento County, California         1363.0               17.0
# 17        El Dorado County, California         1308.0              104.0
# 18         Monterey County, California         1658.0               53.0
# 19    San Francisco County, California         1959.0               63.0
# 20        San Diego County, California         1758.0               13.0
# 21           Tulare County, California         1014.0               44.0
# 22         Humboldt County, California         1006.0               61.0
# 23           Madera County, California         1028.0               90.0
# 24       Santa Cruz County, California         1785.0               82.0
# 25        Riverside County, California         1497.0               33.0
# 26   San Bernardino County, California         1342.0               29.0
# 27            Marin County, California         2096.0               95.0
# 28           Placer County, California         1640.0               78.0
# 29           Shasta County, California         1116.0               74.0
# 30           Solano County, California         1723.0               53.0
# 31            Butte County, California         1087.0               69.0
# 32            Kings County, California          969.0               68.0
# 33  San Luis Obispo County, California         1654.0               56.0
# 34           Fresno County, California         1034.0               25.0
# 35             Kern County, California          949.0               27.0
# 36           Orange County, California         1929.0               22.0
# 37          Ventura County, California         1859.0               45.0
# 38           Sutter County, California         1151.0               98.0
# 39        San Mateo County, California         2497.0               62.0
# 40      San Joaquin County, California         1260.0               46.0
#
#     med_rent_2023  med_rent_2023_moe
# 0          1544.0              173.0
# 1          1304.0               91.0
# 2          2061.0               75.0
# 3          1022.0               69.0
# 4          2303.0               37.0
# 5          2239.0              183.0
# 6          1900.0               83.0
# 7          1782.0              129.0
# 8          1439.0              110.0
# 9          1896.0               11.0
# 10         2781.0               37.0
# 11         1294.0               59.0
# 12         2314.0               59.0
# 13         1595.0               54.0
# 14         1988.0               71.0
# 15         1126.0               98.0
# 16         1762.0               28.0
# 17         1761.0              185.0
# 18         2004.0               80.0
# 19         2356.0               66.0
# 20         2296.0               22.0
# 21         1277.0               51.0
# 22         1246.0               74.0
# 23         1477.0              118.0
# 24         2055.0              101.0
# 25         1871.0               38.0
# 26         1831.0               33.0
# 27         2614.0              144.0
# 28         2009.0               96.0
# 29         1351.0              113.0
# 30         2059.0               64.0
# 31         1434.0               85.0
# 32         1220.0               68.0
# 33         1922.0               89.0
# 34         1410.0               39.0
# 35         1286.0               35.0
# 36         2382.0               24.0
# 37         2264.0               65.0
# 38         1403.0              122.0
# 39         2797.0               70.0
# 40         1655.0               49.0

# %%
# filter rows where med_rent_2019_adj > med_rent_2023
mask = df['med_rent_2019'] > df['med_rent_2023']

# print the NAME column for those rows
print(df.loc[mask, 'NAME'])
# Out:
# Series([], Name: NAME, dtype: object)

# %%
# Inflation factor (2019 -> 2023 dollars)
inflation_factor = 305.109 / 255.657  # ≈ 1.193

# Adjust 2019 median rent
df["med_rent_2019_adj"] = df["med_rent_2019"] * inflation_factor
df["med_rent_2019_adj_moe"] = df["med_rent_2019_moe"] * inflation_factor
df[["NAME", "med_rent_2019", "med_rent_2019_adj", "med_rent_2023"]]
# Out:
#                                   NAME  med_rent_2019  med_rent_2019_adj  \
# 0              Lake County, California          992.0        1183.883594
# 1              Yuba County, California         1012.0        1207.752215
# 2            Sonoma County, California         1757.0        2096.858341
# 3          Imperial County, California          810.0         966.679144
# 4           Alameda County, California         1982.0        2365.380326
# 5              Napa County, California         1835.0        2189.945963
# 6              Yolo County, California         1489.0        1777.018822
# 7            Nevada County, California         1407.0        1679.157477
# 8         Mendocino County, California         1120.0        1336.642767
# 9       Los Angeles County, California         1577.0        1882.040754
# 10      Santa Clara County, California         2392.0        2854.687053
# 11           Merced County, California         1097.0        1309.193853
# 12     Contra Costa County, California         1948.0        2324.803671
# 13       Stanislaus County, California         1231.0        1469.113613
# 14    Santa Barbara County, California         1660.0        1981.095530
# 15           Tehama County, California          950.0        1133.759490
# 16       Sacramento County, California         1363.0        1626.646511
# 17        El Dorado County, California         1308.0        1561.007803
# 18         Monterey County, California         1658.0        1978.708668
# 19    San Francisco County, California         1959.0        2337.931412
# 20        San Diego County, California         1758.0        2098.051772
# 21           Tulare County, California         1014.0        1210.139077
# 22         Humboldt County, California         1006.0        1200.591629
# 23           Madera County, California         1028.0        1226.847112
# 24       Santa Cruz County, California         1785.0        2130.274411
# 25        Riverside County, California         1497.0        1786.566270
# 26   San Bernardino County, California         1342.0        1601.584459
# 27            Marin County, California         2096.0        2501.431465
# 28           Placer County, California         1640.0        1957.226909
# 29           Shasta County, California         1116.0        1331.869043
# 30           Solano County, California         1723.0        2056.281686
# 31            Butte County, California         1087.0        1297.259543
# 32            Kings County, California          969.0        1156.434680
# 33  San Luis Obispo County, California         1654.0        1973.934944
# 34           Fresno County, California         1034.0        1234.007698
# 35             Kern County, California          949.0        1132.566059
# 36           Orange County, California         1929.0        2302.128481
# 37          Ventura County, California         1859.0        2218.588308
# 38           Sutter County, California         1151.0        1373.639130
# 39        San Mateo County, California         2497.0        2979.997313
# 40      San Joaquin County, California         1260.0        1503.723113
#
#     med_rent_2023
# 0          1544.0
# 1          1304.0
# 2          2061.0
# 3          1022.0
# 4          2303.0
# 5          2239.0
# 6          1900.0
# 7          1782.0
# 8          1439.0
# 9          1896.0
# 10         2781.0
# 11         1294.0
# 12         2314.0
# 13         1595.0
# 14         1988.0
# 15         1126.0
# 16         1762.0
# 17         1761.0
# 18         2004.0
# 19         2356.0
# 20         2296.0
# 21         1277.0
# 22         1246.0
# 23         1477.0
# 24         2055.0
# 25         1871.0
# 26         1831.0
# 27         2614.0
# 28         2009.0
# 29         1351.0
# 30         2059.0
# 31         1434.0
# 32         1220.0
# 33         1922.0
# 34         1410.0
# 35         1286.0
# 36         2382.0
# 37         2264.0
# 38         1403.0
# 39         2797.0
# 40         1655.0

# %%
# filter rows where med_rent_2019_adj > med_rent_2023
mask = df['med_rent_2019_adj'] > df['med_rent_2023']

# print the NAME column for those rows
print(df.loc[mask, 'NAME'])
# Out:
# 2              Sonoma County, California
# 4             Alameda County, California
# 10        Santa Clara County, California
# 11             Merced County, California
# 12       Contra Costa County, California
# 15             Tehama County, California
# 24         Santa Cruz County, California
# 33    San Luis Obispo County, California
# 39          San Mateo County, California
# Name: NAME, dtype: object

# %% [markdown]
# ------------------------
# # 2. Testing for statistically significant differences
#
# ## 2.1 Calculating standard errors
#
# First we need to convert the 90% confidence level margins of error that come with the ACS data into standard errors. The formula to do so is $SE = \frac{MOE_{ACS}}{1.645},$ where $MOE_{ACS}$ is the 90% margin of error provided for the ACS estimate.
#
# Let's calculate the standard error for the estimates of the percent of renters who are cost burdened. Try implementing this formula for this estimate's standard error now.

# %%
# Create a new 'pct_rent_burdened_se' column based on 'pct_rent_burdened_moe'
df['med_rent_2019_adj_se'] = df['med_rent_2019_adj_moe'] / 1.645
df['med_rent_2023_se'] = df['med_rent_2023_moe'] / 1.645

# %% [markdown]
# ## 2.2 Implementing the two-sample t-test of means
#
# Let's review the formula for testing whether two sample estimates are statistically significantly different from each other:
#
# $$\left|\frac{\hat{X}_1 - \hat{X}_2}{\sqrt{SE_1^2 + SE_2^2}}\right| > Z_{CL},$$
# where:
# * $\hat{X}_1$ and $\hat{X}_2$ are the estimates we're comparing (the hat over the $X$ just means that the value is an estimate)
# * $SE_1$ and $SE_2$ are the corresponding *standard error* values, and
# * $Z_{CL}$ is the z-score associated with a given *confidence level* (1.645 for 90%, 1.96 for 95%, 2.576 for 99%).
#
# We have all our “ingredients” – we have the percent of renters who are cost burdened for each geography, as well as the associated standard error. Now we just need to implement this formula. It looks complicated, but we already know addition `+`, subtraction `-`, division `-`, and exponentiation `**` in Python. All we really need to complete the picture is how to take the *absolute value* of a number.
#
# The absolute value of a real number $x$ is the non-negative value of $x$, without regard to its sign. In math formulas, $|x|$ denotes an absolute value. In Python, the function `abs(x)` returns the value of `x` if `x` is non-negative, or `-x` if `x` is negative. So `abs(4)` is 4, and `abs(-10)` is 10.

# %%
# Now try to recreate the above formula:
df['Z_score']=abs((df['med_rent_2023'] - df['med_rent_2019_adj']) / ((df['med_rent_2023_se']**2 + df['med_rent_2019_adj_se']**2)**0.5))
df['pct_increase']=(df['med_rent_2023'] - df['med_rent_2019_adj'])/df['med_rent_2019_adj']
df
# Out:
#                                   NAME  med_rent_2019  med_rent_2019_moe  \
# 0              Lake County, California          992.0              202.0
# 1              Yuba County, California         1012.0               80.0
# 2            Sonoma County, California         1757.0               57.0
# 3          Imperial County, California          810.0               75.0
# 4           Alameda County, California         1982.0               41.0
# 5              Napa County, California         1835.0              124.0
# 6              Yolo County, California         1489.0               74.0
# 7            Nevada County, California         1407.0              130.0
# 8         Mendocino County, California         1120.0              103.0
# 9       Los Angeles County, California         1577.0                9.0
# 10      Santa Clara County, California         2392.0               31.0
# 11           Merced County, California         1097.0               62.0
# 12     Contra Costa County, California         1948.0               50.0
# 13       Stanislaus County, California         1231.0               39.0
# 14    Santa Barbara County, California         1660.0               54.0
# 15           Tehama County, California          950.0              161.0
# 16       Sacramento County, California         1363.0               17.0
# 17        El Dorado County, California         1308.0              104.0
# 18         Monterey County, California         1658.0               53.0
# 19    San Francisco County, California         1959.0               63.0
# 20        San Diego County, California         1758.0               13.0
# 21           Tulare County, California         1014.0               44.0
# 22         Humboldt County, California         1006.0               61.0
# 23           Madera County, California         1028.0               90.0
# 24       Santa Cruz County, California         1785.0               82.0
# 25        Riverside County, California         1497.0               33.0
# 26   San Bernardino County, California         1342.0               29.0
# 27            Marin County, California         2096.0               95.0
# 28           Placer County, California         1640.0               78.0
# 29           Shasta County, California         1116.0               74.0
# 30           Solano County, California         1723.0               53.0
# 31            Butte County, California         1087.0               69.0
# 32            Kings County, California          969.0               68.0
# 33  San Luis Obispo County, California         1654.0               56.0
# 34           Fresno County, California         1034.0               25.0
# 35             Kern County, California          949.0               27.0
# 36           Orange County, California         1929.0               22.0
# 37          Ventura County, California         1859.0               45.0
# 38           Sutter County, California         1151.0               98.0
# 39        San Mateo County, California         2497.0               62.0
# 40      San Joaquin County, California         1260.0               46.0
#
#     med_rent_2023  med_rent_2023_moe  med_rent_2019_adj  \
# 0          1544.0              173.0        1183.883594
# 1          1304.0               91.0        1207.752215
# 2          2061.0               75.0        2096.858341
# 3          1022.0               69.0         966.679144
# 4          2303.0               37.0        2365.380326
# 5          2239.0              183.0        2189.945963
# 6          1900.0               83.0        1777.018822
# 7          1782.0              129.0        1679.157477
# 8          1439.0              110.0        1336.642767
# 9          1896.0               11.0        1882.040754
# 10         2781.0               37.0        2854.687053
# 11         1294.0               59.0        1309.193853
# 12         2314.0               59.0        2324.803671
# 13         1595.0               54.0        1469.113613
# 14         1988.0               71.0        1981.095530
# 15         1126.0               98.0        1133.759490
# 16         1762.0               28.0        1626.646511
# 17         1761.0              185.0        1561.007803
# 18         2004.0               80.0        1978.708668
# 19         2356.0               66.0        2337.931412
# 20         2296.0               22.0        2098.051772
# 21         1277.0               51.0        1210.139077
# 22         1246.0               74.0        1200.591629
# 23         1477.0              118.0        1226.847112
# 24         2055.0              101.0        2130.274411
# 25         1871.0               38.0        1786.566270
# 26         1831.0               33.0        1601.584459
# 27         2614.0              144.0        2501.431465
# 28         2009.0               96.0        1957.226909
# 29         1351.0              113.0        1331.869043
# 30         2059.0               64.0        2056.281686
# 31         1434.0               85.0        1297.259543
# 32         1220.0               68.0        1156.434680
# 33         1922.0               89.0        1973.934944
# 34         1410.0               39.0        1234.007698
# 35         1286.0               35.0        1132.566059
# 36         2382.0               24.0        2302.128481
# 37         2264.0               65.0        2218.588308
# 38         1403.0              122.0        1373.639130
# 39         2797.0               70.0        2979.997313
# 40         1655.0               49.0        1503.723113
#
#     med_rent_2019_adj_moe  med_rent_2019_adj_se  med_rent_2023_se    Z_score  \
# 0              241.073071            146.548979        105.167173   1.996438
# 1               95.474483             58.039200         55.319149   1.200403
# 2               68.025569             41.352930         45.592705   0.582561
# 3               89.507328             54.411750         41.945289   0.805222
# 4               48.930673             29.745090         22.492401   1.672762
# 5              147.985449             89.960759        111.246201   0.342870
# 6               88.313897             53.686260         50.455927   1.669237
# 7              155.146036             94.313699         78.419453   0.838458
# 8              122.923397             74.725470         66.869301   1.020749
# 9               10.740879              6.529410          6.686930   1.493602
# 10              36.996362             22.490190         22.492401   2.316657
# 11              73.992725             44.980380         35.866261   0.264106
# 12              59.671552             36.274500         35.866261   0.211787
# 13              46.543811             28.294110         32.826748   2.904781
# 14              64.445276             39.176460         43.161094   0.118451
# 15             192.142398            116.803889         59.574468   0.059179
# 16              20.288328             12.333330         17.021277   6.439312
# 17             124.116828             75.450960        112.462006   1.476750
# 18              63.251845             38.450970         48.632219   0.407948
# 19              75.186156             45.705870         40.121581   0.297095
# 20              15.514604              9.431370         13.373860  12.095881
# 21              52.510966             31.921560         31.003040   1.502521
# 22              72.799294             44.254890         44.984802   0.719579
# 23             107.408794             65.294100         71.732523   2.578913
# 24              97.861345             59.490180         61.398176   0.880489
# 25              39.383224             23.941170         23.100304   2.537936
# 26              34.609500             21.039210         20.060790   7.891744
# 27             113.375949             68.921550         87.537994   1.010363
# 28              93.087621             56.588220         58.358663   0.636899
# 29              88.313897             53.686260         68.693009   0.219433
# 30              63.251845             38.450970         38.905775   0.049695
# 31              82.346742             50.058810         51.671733   1.900667
# 32              81.153311             49.333320         41.337386   0.987611
# 33              66.832138             40.627440         54.103343   0.767597
# 34              29.835776             18.137250         23.708207   5.895835
# 35              32.222638             19.588230         21.276596   5.305379
# 36              26.255483             15.960780         14.589666   3.693622
# 37              53.704397             32.647050         39.513678   0.885981
# 38             116.956242             71.098020         74.164134   0.285782
# 39              73.992725             44.980380         42.553191   2.955413
# 40              54.897828             33.372540         29.787234   3.381804
#
#     pct_increase
# 0       0.304182
# 1       0.079692
# 2      -0.017101
# 3       0.057228
# 4      -0.026372
# 5       0.022400
# 6       0.069206
# 7       0.061247
# 8       0.076578
# 9       0.007417
# 10     -0.025813
# 11     -0.011606
# 12     -0.004647
# 13      0.085689
# 14      0.003485
# 15     -0.006844
# 16      0.083210
# 17      0.128117
# 18      0.012782
# 19      0.007728
# 20      0.094349
# 21      0.055251
# 22      0.037822
# 23      0.203899
# 24     -0.035336
# 25      0.047260
# 26      0.143243
# 27      0.045002
# 28      0.026452
# 29      0.014364
# 30      0.001322
# 31      0.105407
# 32      0.054967
# 33     -0.026310
# 34      0.142618
# 35      0.135475
# 36      0.034695
# 37      0.020469
# 38      0.021375
# 39     -0.061409
# 40      0.100602

# %%
df_sorted = df.sort_values(by="pct_increase", ascending=False)
df_sorted[["NAME", "pct_increase", "Z_score"]]
# Out:
#                                   NAME  pct_increase    Z_score
# 0              Lake County, California      0.304182   1.996438
# 23           Madera County, California      0.203899   2.578913
# 26   San Bernardino County, California      0.143243   7.891744
# 34           Fresno County, California      0.142618   5.895835
# 35             Kern County, California      0.135475   5.305379
# 17        El Dorado County, California      0.128117   1.476750
# 31            Butte County, California      0.105407   1.900667
# 40      San Joaquin County, California      0.100602   3.381804
# 20        San Diego County, California      0.094349  12.095881
# 13       Stanislaus County, California      0.085689   2.904781
# 16       Sacramento County, California      0.083210   6.439312
# 1              Yuba County, California      0.079692   1.200403
# 8         Mendocino County, California      0.076578   1.020749
# 6              Yolo County, California      0.069206   1.669237
# 7            Nevada County, California      0.061247   0.838458
# 3          Imperial County, California      0.057228   0.805222
# 21           Tulare County, California      0.055251   1.502521
# 32            Kings County, California      0.054967   0.987611
# 25        Riverside County, California      0.047260   2.537936
# 27            Marin County, California      0.045002   1.010363
# 22         Humboldt County, California      0.037822   0.719579
# 36           Orange County, California      0.034695   3.693622
# 28           Placer County, California      0.026452   0.636899
# 5              Napa County, California      0.022400   0.342870
# 38           Sutter County, California      0.021375   0.285782
# 37          Ventura County, California      0.020469   0.885981
# 29           Shasta County, California      0.014364   0.219433
# 18         Monterey County, California      0.012782   0.407948
# 19    San Francisco County, California      0.007728   0.297095
# 9       Los Angeles County, California      0.007417   1.493602
# 14    Santa Barbara County, California      0.003485   0.118451
# 30           Solano County, California      0.001322   0.049695
# 12     Contra Costa County, California     -0.004647   0.211787
# 15           Tehama County, California     -0.006844   0.059179
# 11           Merced County, California     -0.011606   0.264106
# 2            Sonoma County, California     -0.017101   0.582561
# 10      Santa Clara County, California     -0.025813   2.316657
# 33  San Luis Obispo County, California     -0.026310   0.767597
# 4           Alameda County, California     -0.026372   1.672762
# 24       Santa Cruz County, California     -0.035336   0.880489
# 39        San Mateo County, California     -0.061409   2.955413

# %%
# filter rows where med_rent_2019_adj > med_rent_2023
mask = df['Z_score'] < 1.645

# print the NAME column for those rows
print(df.loc[mask, 'NAME'])

# %% [markdown]
# **What does this z-value mean for our analysis?** Can we say the estimates are *statistically significantly different*? If so, at what confidence level?
